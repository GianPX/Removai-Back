# %%
pip install backgroundremover       #instalo modelo
# Out:
# Requirement already satisfied: backgroundremover in /usr/local/lib/python3.10/dist-packages (0.2.8)
# Requirement already satisfied: certifi>=2021.5.30 in /usr/local/lib/python3.10/dist-packages (from backgroundremover) (2024.2.2)
# Requirement already satisfied: charset-normalizer>=2.0.4 in /usr/local/lib/python3.10/dist-packages (from backgroundremover) (3.3.2)
# Requirement already satisfied: filelock>=3.0.12 in /usr/local/lib/python3.10/dist-packages (from backgroundremover) (3.14.0)
# Requirement already satisfied: idna>=3.2 in /usr/local/lib/python3.10/dist-packages (from backgroundremover) (3.7)
# Requirement already satisfied: PySocks>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from backgroundremover) (1.7.1)
# Requirement already satisfied: six>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from backgroundremover) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from backgroundremover) (2.0.7)
# Requirement already satisfied: numpy>=1.19.4 in /usr/local/lib/python3.10/dist-packages (from backgroundremover) (1.25.2)
# Requirement already satisfied: scikit-image>=0.17.2 in /usr/local/lib/python3.10/dist-packages (from backgroundremover) (0.19.3)
# Requirement already satisfied: torch>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from backgroundremover) (2.3.0+cu121)
# Requirement already satisfied: torchvision>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from backgroundremover) (0.18.0+cu121)
# Requirement already satisfied: waitress>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from backgroundremover) (3.0.0)
# Requirement already satisfied: tqdm>=4.51.0 in /usr/local/lib/python3.10/dist-packages (from backgroundremover) (4.66.4)
# Requirement already satisfied: requests>=2.24.0 in /usr/local/lib/python3.10/dist-packages (from backgroundremover) (2.31.0)
# Requirement already satisfied: scipy>=1.5.4 in /usr/local/lib/python3.10/dist-packages (from backgroundremover) (1.11.4)
# Requirement already satisfied: pymatting>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from backgroundremover) (1.1.12)
# Requirement already satisfied: filetype>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from backgroundremover) (1.2.0)
# Requirement already satisfied: hsh>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from backgroundremover) (1.1.0)
# Requirement already satisfied: more-itertools>=8.7.0 in /usr/local/lib/python3.10/dist-packages (from backgroundremover) (10.1.0)
# Requirement already satisfied: moviepy>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from backgroundremover) (1.0.3)
# Requirement already satisfied: Pillow<10.0.0,>=8.1.1 in /usr/local/lib/python3.10/dist-packages (from backgroundremover) (9.4.0)
# Requirement already satisfied: ffmpeg-python in /usr/local/lib/python3.10/dist-packages (from backgroundremover) (0.2.0)
# Requirement already satisfied: commandlines in /usr/local/lib/python3.10/dist-packages (from hsh>=1.1.0->backgroundremover) (0.4.1)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.10/dist-packages (from moviepy>=1.0.3->backgroundremover) (4.4.2)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.10/dist-packages (from moviepy>=1.0.3->backgroundremover) (0.1.10)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.10/dist-packages (from moviepy>=1.0.3->backgroundremover) (2.31.6)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from moviepy>=1.0.3->backgroundremover) (0.4.9)
# Requirement already satisfied: numba!=0.49.0 in /usr/local/lib/python3.10/dist-packages (from pymatting>=1.1.1->backgroundremover) (0.58.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.17.2->backgroundremover) (3.3)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.17.2->backgroundremover) (2024.5.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.17.2->backgroundremover) (1.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.17.2->backgroundremover) (24.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->backgroundremover) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->backgroundremover) (1.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->backgroundremover) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->backgroundremover) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->backgroundremover) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->backgroundremover) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->backgroundremover) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->backgroundremover) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->backgroundremover) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->backgroundremover) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->backgroundremover) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->backgroundremover) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->backgroundremover) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->backgroundremover) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->backgroundremover) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->backgroundremover) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.7.0->backgroundremover) (12.5.40)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from ffmpeg-python->backgroundremover) (0.18.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from imageio-ffmpeg>=0.2.0->moviepy>=1.0.3->backgroundremover) (67.7.2)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba!=0.49.0->pymatting>=1.1.1->backgroundremover) (0.41.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7.0->backgroundremover) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7.0->backgroundremover) (1.3.0)

# %%
# !ls /content                       #para saber si guardo el archivo
# Out:
# prueba-ia.mp4  sample_data

# %%
import cv2

# Define the input video path
input_path = "/content/prueba-ia.mp4"

# Open the video file
cap = cv2.VideoCapture(input_path)

# Extract frames from the video
frames = []
while True:
    ret, frame = cap.read()
    if not ret:
        break
    frames.append(frame)

# Release the video capture object
cap.release()

# %%
import backgroundremover.bg as bg
import io
from PIL import Image
import numpy as np

# Process each frame in the list
processed_frames = []
for frame in frames:
    # Convert the frame to RGB format
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Convert the NumPy array to a PIL Image object
    frame_pil = Image.fromarray(frame_rgb)

    # Convert the PIL Image object to a byte-like object
    frame_bytes = io.BytesIO()
    frame_pil.save(frame_bytes, format='PNG')

   # Remove the background
    masked_frame = bg.remove(frame_bytes.getvalue())

    # Convert the masked frame back to BGR format
    masked_frame_bgr = cv2.cvtColor(np.array(masked_frame), cv2.COLOR_RGB2BGR)

    # Add the processed frame to the list
    processed_frames.append(masked_frame_bgr)
# Out:
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth
# DEBUG: path to be checked: /root/.u2net/u2net.pth

# %%
# Define the output video file path
output_video_path = "/content/processed_output.mp4"

# Get the frame size from the input video
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Define the video writer object
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
fps = cap.get(cv2.CAP_PROP_FPS)
out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

# Write the processed frames to the output video file
for frame in processed_frames:
    out.write(frame)

# Write the processed frames to the output video file
for frame in processed_frames:
    out.write(frame)

# Release the video writer object
out.release()

# %%
import os

# Get the current working directory
cwd = os.getcwd()

# Construct the path to the output video file
output_video_path = os.path.join(cwd, "processed_output.mp4")

# Print the path
print(output_video_path)
# Out:
# /content/processed_output.mp4
